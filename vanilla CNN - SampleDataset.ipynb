# %% [markdown]
# # With rgb images

# %% [markdown]
# ### Load data

# %%
import pickle

train_filename = "C:/Users/behl/Desktop/lung disease/train_data_sample_rgb.p"
(train_labels, train_data, train_tensors) = pickle.load(open(train_filename, mode='rb'))

valid_filename = "C:/Users/behl/Desktop/lung disease/valid_data_sample_rgb.p"
(valid_labels, valid_data, valid_tensors) = pickle.load(open(valid_filename, mode='rb'))

test_filename = "C:/Users/behl/Desktop/lung disease/test_data_sample_rgb.p"
(test_labels, test_data, test_tensors) = pickle.load(open(test_filename, mode='rb'))

# %% [markdown]
# ### CNN model

# %%
import time

from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from tensorflow.keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras import regularizers, initializers, optimizers

model = Sequential()

model.add(Conv2D(filters=16, 
                 kernel_size=7,
                 padding='same', 
                 activation='relu', 
                 input_shape=train_tensors.shape[1:]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=32, 
                 kernel_size=5,
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=64, 
                 kernel_size=5,
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=128, 
                 kernel_size=5,
                 strides=2,
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 64, 64, 16)        2368
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        12832
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 128)         204928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               51300
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 322,793
# Trainable params: 322,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import backend as K

def binary_accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

def precision_threshold(threshold = 0.5):
    def precision(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(y_pred)
        precision_ratio = true_positives / (predicted_positives + K.epsilon())
        return precision_ratio
    return precision

def recall_threshold(threshold = 0.5):
    def recall(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.clip(y_true, 0, 1))
        recall_ratio = true_positives / (possible_positives + K.epsilon())
        return recall_ratio
    return recall

def fbeta_score_threshold(beta = 1, threshold = 0.5):
    def fbeta_score(y_true, y_pred):
        threshold_value = threshold
        beta_value = beta
        p = precision_threshold(threshold_value)(y_true, y_pred)
        r = recall_threshold(threshold_value)(y_true, y_pred)
        bb = beta_value ** 2
        fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta_score
    return fbeta_score

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', 
              metrics=[precision_threshold(threshold = 0.5), 
                       recall_threshold(threshold = 0.5), 
                       fbeta_score_threshold(beta=0.5, threshold = 0.5),
                      'accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping
import numpy as np

epochs = 20
batch_size = 32

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')
log = CSVLogger('C:/Users/behl/Desktop/lung disease/log_bCNN_rgb.csv')
checkpointer = ModelCheckpoint(filepath='C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

start = time.time()

model.fit(train_tensors, train_labels, 
          validation_data=(valid_tensors, valid_labels),
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer, log, earlystop], verbose=1)

# Show total training time
print("training time: %.2f minutes"%((time.time()-start)/60))
# Out:
# Train on 3400 samples, validate on 1100 samples
# Epoch 1/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6865 - precision: 0.0214 - recall: 0.0339 - fbeta_score: 0.0212 - accuracy: 0.5510
# Epoch 00001: val_loss improved from inf to 0.68607, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 18s 5ms/sample - loss: 0.6866 - precision: 0.0212 - recall: 0.0335 - fbeta_score: 0.0210 - accuracy: 0.5506 - val_loss: 0.6861 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_accuracy: 0.5482
# Epoch 2/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6826 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - accuracy: 0.5590
# Epoch 00002: val_loss improved from 0.68607 to 0.68453, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 16s 5ms/sample - loss: 0.6827 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - accuracy: 0.5585 - val_loss: 0.6845 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_accuracy: 0.5482
# Epoch 3/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6805 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - accuracy: 0.5587
# Epoch 00003: val_loss improved from 0.68453 to 0.68240, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 17s 5ms/sample - loss: 0.6806 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - accuracy: 0.5585 - val_loss: 0.6824 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_accuracy: 0.5482
# Epoch 4/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6776 - precision: 0.0802 - recall: 0.0152 - fbeta_score: 0.0379 - accuracy: 0.5604
# Epoch 00004: val_loss improved from 0.68240 to 0.68048, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 18s 5ms/sample - loss: 0.6777 - precision: 0.0794 - recall: 0.0151 - fbeta_score: 0.0375 - accuracy: 0.5600 - val_loss: 0.6805 - val_precision: 0.6839 - val_recall: 0.2166 - val_fbeta_score: 0.4564 - val_accuracy: 0.5973
# Epoch 5/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6735 - precision: 0.3945 - recall: 0.0996 - fbeta_score: 0.2106 - accuracy: 0.5767
# Epoch 00005: val_loss did not improve from 0.68048
# 3400/3400 [==============================] - 17s 5ms/sample - loss: 0.6733 - precision: 0.3908 - recall: 0.0987 - fbeta_score: 0.2086 - accuracy: 0.5774 - val_loss: 0.6924 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_accuracy: 0.5482
# Epoch 6/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6679 - precision: 0.5191 - recall: 0.2275 - fbeta_score: 0.3606 - accuracy: 0.5943
# Epoch 00006: val_loss improved from 0.68048 to 0.66701, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 16s 5ms/sample - loss: 0.6680 - precision: 0.5143 - recall: 0.2253 - fbeta_score: 0.3573 - accuracy: 0.5941 - val_loss: 0.6670 - val_precision: 0.6829 - val_recall: 0.2758 - val_fbeta_score: 0.5093 - val_accuracy: 0.6100
# Epoch 7/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6648 - precision: 0.5998 - recall: 0.3219 - fbeta_score: 0.4593 - accuracy: 0.6076
# Epoch 00007: val_loss improved from 0.66701 to 0.66497, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 17s 5ms/sample - loss: 0.6649 - precision: 0.5966 - recall: 0.3220 - fbeta_score: 0.4575 - accuracy: 0.6071 - val_loss: 0.6650 - val_precision: 0.6834 - val_recall: 0.2861 - val_fbeta_score: 0.5179 - val_accuracy: 0.6109
# Epoch 8/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6611 - precision: 0.6181 - recall: 0.3555 - fbeta_score: 0.4929 - accuracy: 0.6038
# Epoch 00008: val_loss improved from 0.66497 to 0.66180, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 16s 5ms/sample - loss: 0.6612 - precision: 0.6170 - recall: 0.3545 - fbeta_score: 0.4921 - accuracy: 0.6035 - val_loss: 0.6618 - val_precision: 0.6075 - val_recall: 0.4115 - val_fbeta_score: 0.5447 - val_accuracy: 0.6118
# Epoch 9/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6587 - precision: 0.5978 - recall: 0.3832 - fbeta_score: 0.5033 - accuracy: 0.6135
# Epoch 00009: val_loss did not improve from 0.66180
# 3400/3400 [==============================] - 15s 5ms/sample - loss: 0.6588 - precision: 0.5992 - recall: 0.3843 - fbeta_score: 0.5049 - accuracy: 0.6132 - val_loss: 0.6919 - val_precision: 0.4880 - val_recall: 0.8783 - val_fbeta_score: 0.5333 - val_accuracy: 0.5209
# Epoch 10/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6566 - precision: 0.6106 - recall: 0.4147 - fbeta_score: 0.5255 - accuracy: 0.6179
# Epoch 00010: val_loss improved from 0.66180 to 0.65882, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 16s 5ms/sample - loss: 0.6565 - precision: 0.6142 - recall: 0.4164 - fbeta_score: 0.5288 - accuracy: 0.6182 - val_loss: 0.6588 - val_precision: 0.6008 - val_recall: 0.4938 - val_fbeta_score: 0.5672 - val_accuracy: 0.6173
# Epoch 11/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6573 - precision: 0.6009 - recall: 0.4092 - fbeta_score: 0.5239 - accuracy: 0.6194
# Epoch 00011: val_loss improved from 0.65882 to 0.65869, saving model to C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5
# 3400/3400 [==============================] - 16s 5ms/sample - loss: 0.6573 - precision: 0.6009 - recall: 0.4124 - fbeta_score: 0.5248 - accuracy: 0.6194 - val_loss: 0.6587 - val_precision: 0.6026 - val_recall: 0.4880 - val_fbeta_score: 0.5667 - val_accuracy: 0.6191
# Epoch 12/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6549 - precision: 0.6139 - recall: 0.4005 - fbeta_score: 0.5264 - accuracy: 0.6162
# Epoch 00012: val_loss did not improve from 0.65869
# 3400/3400 [==============================] - 16s 5ms/sample - loss: 0.6551 - precision: 0.6175 - recall: 0.3999 - fbeta_score: 0.5281 - accuracy: 0.6159 - val_loss: 0.7019 - val_precision: 0.4839 - val_recall: 0.8928 - val_fbeta_score: 0.5305 - val_accuracy: 0.5136
# Epoch 13/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6553 - precision: 0.6114 - recall: 0.4217 - fbeta_score: 0.5416 - accuracy: 0.6212
# Epoch 00013: val_loss did not improve from 0.65869
# 3400/3400 [==============================] - 15s 4ms/sample - loss: 0.6551 - precision: 0.6150 - recall: 0.4224 - fbeta_score: 0.5443 - accuracy: 0.6215 - val_loss: 0.6592 - val_precision: 0.6227 - val_recall: 0.4058 - val_fbeta_score: 0.5503 - val_accuracy: 0.6155
# Epoch 14/20
# 3392/3400 [============================>.] - ETA: 0s - loss: 0.6541 - precision: 0.6284 - recall: 0.4420 - fbeta_score: 0.5561 - accuracy: 0.6250
# Epoch 00014: val_loss did not improve from 0.65869
# 3400/3400 [==============================] - 15s 4ms/sample - loss: 0.6543 - precision: 0.6272 - recall: 0.4416 - fbeta_score: 0.5553 - accuracy: 0.6244 - val_loss: 0.6623 - val_precision: 0.5812 - val_recall: 0.6103 - val_fbeta_score: 0.5816 - val_accuracy: 0.6200
# Epoch 00014: early stopping
# training time: 3.82 minutes

# %% [markdown]
# ### Metric

# %%
model.load_weights('C:/Users/behl/Desktop/lung disease/bCNN.best.from_scratch.hdf5')
prediction = model.predict(test_tensors)
print("prediction : ",prediction)
# Out:
# prediction :  [[0.35952947]
#  [0.48853812]
#  [0.35816407]
#  [0.5495918 ]
#  [0.4896742 ]
#  [0.3756183 ]
#  [0.33958054]
#  [0.41460478]
#  [0.39357018]
#  [0.62492836]
#  [0.41811556]
#  [0.42484617]
#  [0.66258085]
#  [0.431732  ]
#  [0.34676644]
#  [0.45423985]
#  [0.5434803 ]
#  [0.4915854 ]
#  [0.28965187]
#  [0.26826322]
#  [0.59350455]
#  [0.31966802]
#  [0.3396483 ]
#  [0.6227741 ]
#  [0.3854418 ]
#  [0.32744223]
#  [0.3828693 ]
#  [0.60828936]
#  [0.42556056]
#  [0.4118018 ]
#  [0.47780445]
#  [0.38084736]
#  [0.41738263]
#  [0.4094715 ]
#  [0.5622003 ]
#  [0.49149832]
#  [0.4980952 ]
#  [0.35620612]
#  [0.4367329 ]
#  [0.629926  ]
#  [0.56741977]
#  [0.47670692]
#  [0.34167254]
#  [0.57914835]
#  [0.52061766]
#  [0.48598462]
#  [0.28888804]
#  [0.34921688]
#  [0.40357167]
#  [0.6367646 ]
#  [0.42901433]
#  [0.52885664]
#  [0.40109435]
#  [0.45560098]
#  [0.2793401 ]
#  [0.5718026 ]
#  [0.49445602]
#  [0.3300076 ]
#  [0.33885825]
#  [0.41859818]
#  [0.43269372]
#  [0.29652205]
#  [0.5615706 ]
#  [0.5477281 ]
#  [0.60410756]
#  [0.661713  ]
#  [0.47408876]
#  [0.38235903]
#  [0.3300176 ]
#  [0.4449988 ]
#  [0.41181862]
#  [0.43540582]
#  [0.314609  ]
#  [0.43438023]
#  [0.39973375]
#  [0.47410098]
#  [0.6064817 ]
#  [0.42449236]
#  [0.5229167 ]
#  [0.40927708]
#  [0.57245386]
#  [0.43969628]
#  [0.41044813]
#  [0.41973707]
#  [0.31586275]
#  [0.39147472]
#  [0.5250053 ]
#  [0.50667787]
#  [0.5747791 ]
#  [0.5593119 ]
#  [0.49944967]
#  [0.49390525]
#  [0.34729713]
#  [0.51110846]
#  [0.32570457]
#  [0.39196533]
#  [0.5452282 ]
#  [0.5109707 ]
#  [0.3720225 ]
#  [0.32723737]
#  [0.41579902]
#  [0.6588063 ]
#  [0.5795612 ]
#  [0.52534306]
#  [0.6051653 ]
#  [0.5504229 ]
#  [0.47355157]
#  [0.38679844]
#  [0.38586608]
#  [0.58241093]
#  [0.3081682 ]
#  [0.59460354]
#  [0.5691125 ]
#  [0.65338695]
#  [0.47300577]
#  [0.36307585]
#  [0.41846922]
#  [0.6151423 ]
#  [0.6665223 ]
#  [0.637664  ]
#  [0.56652933]
#  [0.62401235]
#  [0.55294806]
#  [0.56397164]
#  [0.44569957]
#  [0.620161  ]
#  [0.44417796]
#  [0.42491415]
#  [0.2793571 ]
#  [0.4458542 ]
#  [0.39813012]
#  [0.45742324]
#  [0.42444283]
#  [0.5203463 ]
#  [0.47241503]
#  [0.47488388]
#  [0.30449948]
#  [0.6395011 ]
#  [0.5357535 ]
#  [0.4827427 ]
#  [0.42564705]
#  [0.43977112]
#  [0.5289437 ]
#  [0.4477558 ]
#  [0.59617656]
#  [0.36753953]
#  [0.4529339 ]
#  [0.28172523]
#  [0.36442545]
#  [0.41694474]
#  [0.49521247]
#  [0.5314757 ]
#  [0.3349019 ]
#  [0.5883408 ]
#  [0.36420792]
#  [0.37278193]
#  [0.6953242 ]
#  [0.4288271 ]
#  [0.6448337 ]
#  [0.4293541 ]
#  [0.42736238]
#  [0.36348638]
#  [0.36734825]
#  [0.37079102]
#  [0.40850985]
#  [0.38612664]
#  [0.42730063]
#  [0.39776427]
#  [0.6358666 ]
#  [0.45207694]
#  [0.5990352 ]
#  [0.25230622]
#  [0.5663504 ]
#  [0.36022145]
#  [0.6182754 ]
#  [0.57247967]
#  [0.6559141 ]
#  [0.5305013 ]
#  [0.53780884]
#  [0.33035028]
#  [0.38696176]
#  [0.67238367]
#  [0.3288173 ]
#  [0.37843218]
#  [0.40614706]
#  [0.52308446]
#  [0.51997834]
#  [0.71985227]
#  [0.51656824]
#  [0.4798586 ]
#  [0.38417628]
#  [0.3690766 ]
#  [0.66785973]
#  [0.52296174]
#  [0.3346534 ]
#  [0.43163767]
#  [0.5688835 ]
#  [0.5291553 ]
#  [0.5494431 ]]

# %%
threshold = 0.5
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f %%\nFscore: %f %%"% (pre, rec, fsc))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-58ff06de31c0> in <module>
#       3
#       4 pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
# ----> 5                                    K.variable(value=prediction)))
#       6 rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
#       7                                    K.variable(value=prediction)))
#
# c:\users\behl\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py in eval(x)
#     671     ```
#     672     """
# --> 673     return to_dense(x).eval(session=get_session())
#     674
#     675
#
# c:\users\behl\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     172     global _SESSION
#     173
# --> 174     default_session = tf.get_default_session()
#     175
#     176     if default_session is not None:
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_session'

# %%
K.eval(binary_accuracy(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
# Out:
# 0.50258511

# %%
prediction[:30]
# Out:
# array([[ 0.46597424],
#        [ 0.57600302],
#        [ 0.30108091],
#        [ 0.50593966],
#        [ 0.61561286],
#        [ 0.6416322 ],
#        [ 0.29955843],
#        [ 0.30611175],
#        [ 0.42266327],
#        [ 0.40697429],
#        [ 0.48799837],
#        [ 0.34801716],
#        [ 0.55648535],
#        [ 0.52279401],
#        [ 0.62823325],
#        [ 0.35642451],
#        [ 0.50304908],
#        [ 0.42197177],
#        [ 0.72991049],
#        [ 0.50801474],
#        [ 0.31001693],
#        [ 0.49956188],
#        [ 0.50922167],
#        [ 0.47676209],
#        [ 0.36952221],
#        [ 0.3691574 ],
#        [ 0.63229394],
#        [ 0.49165967],
#        [ 0.53164726],
#        [ 0.54903966]], dtype=float32)

# %%
threshold = 0.4
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f %%\nFscore: %f %%"% (pre, rec, fsc))
# Out:
# Precision: 0.543257 %
# Recall: 0.816444 %
# Fscore: 0.582220 %

# %%
threshold = 0.6
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f %%\nFscore: %f %%"% (pre, rec, fsc))
# Out:
# Precision: 0.672000 %
# Recall: 0.321224 %
# Fscore: 0.551543 %

# %% [markdown]
# # With gray images

# %%
import pickle

train_filename = "data_preprocessed/train_data_sample_gray.p"
(train_labels, train_data, train_tensors) = pickle.load(open(train_filename, mode='rb'))

valid_filename = "data_preprocessed/valid_data_sample_gray.p"
(valid_labels, valid_data, valid_tensors) = pickle.load(open(valid_filename, mode='rb'))

test_filename = "data_preprocessed/test_data_sample_gray.p"
(test_labels, test_data, test_tensors) = pickle.load(open(test_filename, mode='rb'))

# %%
import time

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras import regularizers, initializers, optimizers

model = Sequential()

model.add(Conv2D(filters=16, 
                 kernel_size=7,
                 padding='same', 
                 activation='relu', 
                 input_shape=train_tensors.shape[1:]))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=32, 
                 kernel_size=5,
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=64, 
                 kernel_size=5,
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=128, 
                 kernel_size=5,
                 strides=2,
                 padding='same', 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 64, 64, 16)        800
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        12832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 128)         204928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               51300
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 321,225
# Trainable params: 321,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import backend as K

def binary_accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

def precision_threshold(threshold = 0.5):
    def precision(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(y_pred)
        precision_ratio = true_positives / (predicted_positives + K.epsilon())
        return precision_ratio
    return precision

def recall_threshold(threshold = 0.5):
    def recall(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.clip(y_true, 0, 1))
        recall_ratio = true_positives / (possible_positives + K.epsilon())
        return recall_ratio
    return recall

def fbeta_score_threshold(beta = 1, threshold = 0.5):
    def fbeta_score(y_true, y_pred):
        threshold_value = threshold
        beta_value = beta
        p = precision_threshold(threshold_value)(y_true, y_pred)
        r = recall_threshold(threshold_value)(y_true, y_pred)
        bb = beta_value ** 2
        fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta_score
    return fbeta_score

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', 
              metrics=[precision_threshold(threshold = 0.5), 
                       recall_threshold(threshold = 0.5), 
                       fbeta_score_threshold(beta=0.5, threshold = 0.5),
                      'accuracy'])

# %%
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping
import numpy as np

epochs = 20
batch_size = 32

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')
log = CSVLogger('saved_models/log_bCNN_gray.csv')
checkpointer = ModelCheckpoint(filepath='saved_models/bCNN_gray.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

start = time.time()

model.fit(train_tensors, train_labels, 
          validation_data=(valid_tensors, valid_labels),
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer, log, earlystop], verbose=1)

# Show total training time
print("training time: %.2f minutes"%((time.time()-start)/60))
# Out:
# Train on 3400 samples, validate on 1100 samples
# Epoch 1/20
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.6900 - precision: 0.1182 - recall: 0.2178 - fbeta_score: 0.1266 - acc: 0.5373Epoch 00001: val_loss improved from inf to 0.69002, saving model to saved_models/bCNN_gray.best.from_scratch.hdf5
# 3400/3400 [==============================] - 2s 682us/step - loss: 0.6901 - precision: 0.1157 - recall: 0.2131 - fbeta_score: 0.1239 - acc: 0.5359 - val_loss: 0.6900 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_acc: 0.5291
# Epoch 2/20
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.6877 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - acc: 0.5405Epoch 00002: val_loss improved from 0.69002 to 0.68985, saving model to saved_models/bCNN_gray.best.from_scratch.hdf5
# 3400/3400 [==============================] - 2s 569us/step - loss: 0.6877 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - acc: 0.5409 - val_loss: 0.6899 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_acc: 0.5291
# Epoch 3/20
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.6861 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - acc: 0.5399Epoch 00003: val_loss did not improve
# 3400/3400 [==============================] - 2s 563us/step - loss: 0.6859 - precision: 0.0000e+00 - recall: 0.0000e+00 - fbeta_score: 0.0000e+00 - acc: 0.5409 - val_loss: 0.6921 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_acc: 0.5291
# Epoch 4/20
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.6837 - precision: 0.0096 - recall: 7.3964e-04 - fbeta_score: 0.0028 - acc: 0.5406    Epoch 00004: val_loss improved from 0.68985 to 0.68468, saving model to saved_models/bCNN_gray.best.from_scratch.hdf5
# 3400/3400 [==============================] - 2s 574us/step - loss: 0.6837 - precision: 0.0141 - recall: 0.0014 - fbeta_score: 0.0049 - acc: 0.5403 - val_loss: 0.6847 - val_precision: 0.0727 - val_recall: 0.0063 - val_fbeta_score: 0.0230 - val_acc: 0.5309
# Epoch 5/20
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.6802 - precision: 0.2212 - recall: 0.0330 - fbeta_score: 0.0913 - acc: 0.5473Epoch 00005: val_loss improved from 0.68468 to 0.68110, saving model to saved_models/bCNN_gray.best.from_scratch.hdf5
# 3400/3400 [==============================] - 2s 570us/step - loss: 0.6803 - precision: 0.2186 - recall: 0.0326 - fbeta_score: 0.0902 - acc: 0.5468 - val_loss: 0.6811 - val_precision: 0.2812 - val_recall: 0.0339 - val_fbeta_score: 0.1079 - val_acc: 0.5364
# Epoch 6/20
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.6745 - precision: 0.5036 - recall: 0.1669 - fbeta_score: 0.3177 - acc: 0.5817Epoch 00006: val_loss improved from 0.68110 to 0.67981, saving model to saved_models/bCNN_gray.best.from_scratch.hdf5
# 3400/3400 [==============================] - 2s 569us/step - loss: 0.6746 - precision: 0.5105 - recall: 0.1685 - fbeta_score: 0.3214 - acc: 0.5809 - val_loss: 0.6798 - val_precision: 0.5527 - val_recall: 0.7384 - val_fbeta_score: 0.5775 - val_acc: 0.5891
# Epoch 7/20
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.6672 - precision: 0.6067 - recall: 0.3669 - fbeta_score: 0.4821 - acc: 0.6062Epoch 00007: val_loss did not improve
# 3400/3400 [==============================] - 2s 563us/step - loss: 0.6667 - precision: 0.6079 - recall: 0.3663 - fbeta_score: 0.4841 - acc: 0.6076 - val_loss: 0.6825 - val_precision: 0.5411 - val_recall: 0.0988 - val_fbeta_score: 0.2625 - val_acc: 0.5491
# Epoch 8/20
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.6620 - precision: 0.5974 - recall: 0.4096 - fbeta_score: 0.5063 - acc: 0.5983Epoch 00008: val_loss did not improve
# 3400/3400 [==============================] - 2s 564us/step - loss: 0.6616 - precision: 0.5987 - recall: 0.4100 - fbeta_score: 0.5080 - acc: 0.5988 - val_loss: 0.7088 - val_precision: 0.4828 - val_recall: 0.9658 - val_fbeta_score: 0.5347 - val_acc: 0.4964
# Epoch 9/20
# 3360/3400 [============================>.] - ETA: 0s - loss: 0.6549 - precision: 0.6199 - recall: 0.4667 - fbeta_score: 0.5570 - acc: 0.6214Epoch 00009: val_loss improved from 0.67981 to 0.65802, saving model to saved_models/bCNN_gray.best.from_scratch.hdf5
# 3400/3400 [==============================] - 2s 569us/step - loss: 0.6568 - precision: 0.6173 - recall: 0.4635 - fbeta_score: 0.5541 - acc: 0.6197 - val_loss: 0.6580 - val_precision: 0.6221 - val_recall: 0.4836 - val_fbeta_score: 0.5805 - val_acc: 0.6209
# Epoch 10/20
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.6548 - precision: 0.6294 - recall: 0.4779 - fbeta_score: 0.5588 - acc: 0.6204Epoch 00010: val_loss did not improve
# 3400/3400 [==============================] - 2s 564us/step - loss: 0.6544 - precision: 0.6312 - recall: 0.4814 - fbeta_score: 0.5618 - acc: 0.6209 - val_loss: 0.6714 - val_precision: 0.5552 - val_recall: 0.7640 - val_fbeta_score: 0.5833 - val_acc: 0.5964
# Epoch 11/20
# 3328/3400 [============================>.] - ETA: 0s - loss: 0.6514 - precision: 0.6366 - recall: 0.5072 - fbeta_score: 0.5816 - acc: 0.6232Epoch 00011: val_loss did not improve
# 3400/3400 [==============================] - 2s 564us/step - loss: 0.6521 - precision: 0.6321 - recall: 0.5051 - fbeta_score: 0.5780 - acc: 0.6215 - val_loss: 0.6751 - val_precision: 0.6973 - val_recall: 0.2211 - val_fbeta_score: 0.4559 - val_acc: 0.5773
# Epoch 12/20
# 3296/3400 [============================>.] - ETA: 0s - loss: 0.6508 - precision: 0.6292 - recall: 0.4952 - fbeta_score: 0.5799 - acc: 0.6323Epoch 00012: val_loss did not improve
# 3400/3400 [==============================] - 2s 565us/step - loss: 0.6498 - precision: 0.6315 - recall: 0.5001 - fbeta_score: 0.5829 - acc: 0.6335 - val_loss: 0.6675 - val_precision: 0.6483 - val_recall: 0.3281 - val_fbeta_score: 0.5318 - val_acc: 0.5991
# Epoch 00012: early stopping
# training time: 0.40 minutes

# %%
model.load_weights('saved_models/bCNN_gray.best.from_scratch.hdf5')
prediction = model.predict(test_tensors)

# %%
threshold = 0.5
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f %%\nFscore: %f %%"% (pre, rec, fsc))
# Out:
# Precision: 0.577114 %
# Recall: 0.480331 %
# Fscore: 0.554758 %

# %%
K.eval(binary_accuracy(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
# Out:
# 0.51713276

# %%
prediction[:30]
# Out:
# array([[ 0.3081094 ],
#        [ 0.24159142],
#        [ 0.52262437],
#        [ 0.59462857],
#        [ 0.3100515 ],
#        [ 0.62393486],
#        [ 0.47555083],
#        [ 0.48481095],
#        [ 0.47963724],
#        [ 0.46049529],
#        [ 0.52123272],
#        [ 0.38751996],
#        [ 0.35624275],
#        [ 0.53882909],
#        [ 0.63341409],
#        [ 0.47135681],
#        [ 0.61958778],
#        [ 0.42561847],
#        [ 0.51211774],
#        [ 0.29424879],
#        [ 0.38310093],
#        [ 0.28851342],
#        [ 0.35126474],
#        [ 0.65281165],
#        [ 0.48659411],
#        [ 0.43335259],
#        [ 0.32977027],
#        [ 0.65944982],
#        [ 0.6016748 ],
#        [ 0.62601507]], dtype=float32)

# %%
threshold = 0.4
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f %%\nFscore: %f %%"% (pre, rec, fsc))
# Out:
# Precision: 0.523416 %
# Recall: 0.786749 %
# Fscore: 0.560968 %
